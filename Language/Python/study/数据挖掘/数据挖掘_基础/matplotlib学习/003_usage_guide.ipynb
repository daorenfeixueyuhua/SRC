# %%
# 导入文件
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## A simple example

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4],[1,4,3,2])

# %% [markdown]
# ## Parts of A figure
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# #### figure

# %%
fig = plt.figure()
fig, ax = plt.subplots()
fig, axs = plt.subplots(2, 2)

# %% [markdown]
# ## types of input to plotting function

# %% [markdown]
# #### pandas.DateFrame

# %%
a = pandas.DataFrame(np.random.rand(4, 5), columns=list('abcde'))
a_asarray = a.values 
print(a_asarray)
# Out:
# [[0.23603689 0.74925835 0.59299274 0.12831581 0.66664905]
#  [0.52338697 0.82133093 0.81518645 0.5946555  0.49242924]
#  [0.20917869 0.41922481 0.28472286 0.11609822 0.58584261]
#  [0.0750415  0.88476008 0.26497463 0.20073808 0.16445   ]]

# %% [markdown]
# #### numpy.matrix

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)
print(b_asarray)
# Out:
# [[1 2]
#  [3 4]]

# %% [markdown]
# ## the object-oriented interface

# %%
x = np.linspace(0, 2, 100)

fig, ax = plt.subplots()
ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quedratic')
ax.plot(x, x**3, label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')

ax.set_title('Simle Plot')
ax.legend()

# %% [markdown]
# ## pylot style

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='qurdratic')
plt.plot(x, x**3, label='cubic')
plt.ylabel('y label')
plt.xlabel('x label')
plt.legend()

# %% [markdown]
# ## fancution

# %%
def my_plotter(ax, data1, data2, param_dict):
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1,1)
my_plotter(ax, data1, data2, {'marker':'x'})

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker':'x'})
my_plotter(ax2, data3, data4, {'marker':'o'})

# %% [markdown]
# ## Interative example

# %%
plt.ion()
plt.plot([1.6, 2.7])

# %% [markdown]
# ## Using the fast style

# %%
import matplotlib.style as mplsytle
# mplsytle.use('fast')
mplsytle.use(['dark_background', 'ggplot', 'fast'])

plt.plot(np.random.rand(10))
